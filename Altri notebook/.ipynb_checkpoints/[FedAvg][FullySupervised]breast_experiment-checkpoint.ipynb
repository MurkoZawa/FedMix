# %%
import os
import copy

import numpy as np
import torch
import torch.nn as nn
import math

from torch import optim
from torch.utils.data import Dataset, DataLoader
from torch.nn import functional as F
from unet import UNet
from dice_loss import dice_coeff

####################################################
# for data preparation
####################################################
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.metrics import roc_auc_score, accuracy_score, balanced_accuracy_score
####################################################
# for plotting
####################################################
import matplotlib.pyplot as plt
from IPython.display import clear_output
############################
# Helper func
############################
from helper import * 
#################################
N_CHANNELS, N_CLASSES = 1, 1 
bilinear = True
BATCH_SIZE, EPOCHS = 16, 300
IMAGE_SIZE = (600, 600)
CROP_SIZE = (224, 224)
#########################################
DIR = 'dataset/breast'
CLIENTS = ['miccai', 'bns']
CLIENTS_2 = [cl +'_2' for cl in CLIENTS]
TOTAL_CLIENTS = len(CLIENTS)
#####################################
# add the classification segment ####

# %%
device = torch.device('cuda:0')
LR, WD = 1e-3, 1e-4

LAM, BETA, TH = 10, 1.5,0.9
VERSION = 1
CLIENTS_SUPERVISION = ['labeled', 'labeled']
WEIGHTS_CL = [0.0, 0.0]

# %% [markdown]
# # load training-test path

# %%
import os
import glob
import random

# Definisci il percorso delle cartelle delle immagini e delle etichette
IMAGES_DIR = "C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray"
LABELS_DIR = "C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/labelsTrGray"

breast_dataset = dict()
idx_ = 0
denom_ = 0

for client, sup in zip(CLIENTS, CLIENTS_SUPERVISION):
    # Carica le immagini e le etichette dal percorso specificato
    x_train = glob.glob(os.path.join(IMAGES_DIR, "*.png"))
    y_train = glob.glob(os.path.join(LABELS_DIR, "*.png"))

    # Se il cliente non ha supervisione, aggiungi anche le immagini normali
    if sup == 'unlabeled':
        DATA_TYPE = ['original', 'GT']
        for data in DATA_TYPE:
            # Carica le immagini normali
            normal_images = glob.glob(os.path.join(IMAGES_DIR, "miccai", "classification", data, "normal*.jpg"))
            if data == 'GT':
                y_train += normal_images
            else:
                x_train += normal_images

    # Scegli casualmente il 10% delle immagini e delle etichette come set di test
    num_test_samples = int(0.1 * len(x_train))
    test_indices = random.sample(range(len(x_train)), num_test_samples)
    x_test = [x_train[i] for i in test_indices]
    y_test = [y_train[i] for i in test_indices]
    x_train = [x_train[i] for i in range(len(x_train)) if i not in test_indices]
    y_train = [y_train[i] for i in range(len(y_train)) if i not in test_indices]

    print('Full training data')
    WEIGHTS_CL[idx_] = len(x_train)
    denom_ += len(x_train)
    idx_ += 1
    
    # Carica il dataset utilizzando la classe Cancer (assicurati di avere la definizione di questa classe)
    breast_dataset[client+'_train'] = Cancer(x_train, y_train, train=True,\
                                             IMAGE_SIZE=IMAGE_SIZE, CROP_SIZE=CROP_SIZE)

    # Carica il dataset di test
    breast_dataset[client+'_test'] = Cancer(x_test, y_test, train=False,\
                                            IMAGE_SIZE=IMAGE_SIZE, CROP_SIZE=CROP_SIZE)

# Normalizza i pesi dei clienti
for idx_ in range(len(WEIGHTS_CL)):
    WEIGHTS_CL[idx_] = WEIGHTS_CL[idx_]/denom_
# Out:
# Full training data
# Full training data

# %% [markdown]
# # storage file

# %%
len(breast_dataset[client+'_train'])
# Out:
# 342

# %%
training_clients, testing_clients = dict(), dict()
training_clients_pl = dict()

acc_train, acc_test, loss_train, loss_test = dict(), dict(), \
                                            dict(), dict()
    
nets, optimizers = dict(), dict()

# %%
nets['global'] = UNet(n_channels=N_CHANNELS, n_classes=N_CLASSES, \
                      bilinear=True).to(device)

nets['global_2'] = UNet(n_channels=N_CHANNELS, n_classes=N_CLASSES, \
                      bilinear=True).to(device)

for client in CLIENTS:
    training_clients[client] = DataLoader(breast_dataset[client+'_train'], batch_size=16,\
                 shuffle=True, num_workers=8)
    training_clients_pl[client] = DataLoader(breast_dataset[client+'_train'], batch_size=1, \
                shuffle=True, num_workers=8)
    ###################################################################################
    testing_clients[client] = DataLoader(breast_dataset[client+'_test'], batch_size=1,\
                         shuffle=False, num_workers=1)
    
    acc_train[client], acc_test[client] = [], []
    loss_train[client], loss_test[client] = [], []
        
    nets[client] = UNet(n_channels=N_CHANNELS, n_classes=N_CLASSES, \
                      bilinear=True).to(device)
    nets[client+'_2'] = UNet(n_channels=N_CHANNELS, n_classes=N_CLASSES, \
                      bilinear=True).to(device)
    optimizers[client]= optim.Adam(nets[client].parameters(), \
                                   lr=LR,weight_decay=WD)
    optimizers[client+'_2']= optim.Adam(nets[client+'_2'].parameters(), \
                                   lr=LR,weight_decay=WD)

# %% [markdown]
# ## FedAvg

# %%
best_avg_acc, best_epoch_avg = 0, 0
index = []

for client in CLIENTS:
    acc_train[client], acc_test[client] = [], []
    loss_train[client], loss_test[client] = [], []

for epoch in range(EPOCHS):
    index.append(epoch)
    #################### copy fed model ###################
    copy_fed(CLIENTS, nets, fed_name='global')
    
    #### conduct training #####
    for client, supervision_t in zip(CLIENTS, CLIENTS_SUPERVISION):
        train_model(training_clients[client], nets[client], \
                                  optimizers[client], device, \
                                  acc = acc_train[client], \
                                  loss = loss_train[client], \
                                  supervision_type = supervision_t)
        
    aggr_fed(CLIENTS, WEIGHTS_CL, nets, fed_name='global')
    ################### test ##############################
    avg_acc = 0.0
    for client in CLIENTS:
        test(epoch, testing_clients[client], nets['global'], device, acc_test[client],\
             loss_test[client])
        avg_acc += acc_test[client][-1]
        
    avg_acc = avg_acc / TOTAL_CLIENTS
    ############################################################
    ########################################################
    if avg_acc > best_avg_acc:
        best_avg_acc = avg_acc
        best_epoch = epoch
    
    ################################
    # plot #########################
    ################################
    clear_output(wait=True)
    print(avg_acc, best_avg_acc)
    plt.figure(0)
    plt.plot(index, acc_train['miccai'], colors[1], label='miccai train')
    plt.plot(index, acc_train['bns'], colors[2], label='bns train')

    plt.legend()
    plt.show()

    plt.figure(1)
    plt.plot(index, loss_train['miccai'], colors[1], label='miccai loss train')
    plt.plot(index, loss_train['bns'], colors[2], label='bns loss train')
    plt.legend()
    plt.show()
    
    plot_graphs(2, CLIENTS, index, acc_test, ' acc_test')

print(best_avg_acc, best_epoch)
for client in CLIENTS:
    print(client)
    tmp = best_epoch
    best_epoch = best_epoch 
    print("shared epoch specific")
    print(acc_test[client][best_epoch])
    print("max client-specific")
    print(np.max(acc_test[client]))
    best_epoch = tmp
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[20], line 15
#      13 #### conduct training #####
#      14 for client, supervision_t in zip(CLIENTS, CLIENTS_SUPERVISION):
# ---> 15     train_model(training_clients[client], nets[client], \
#      16                               optimizers[client], device, \
#      17                               acc = acc_train[client], \
#      18                               loss = loss_train[client], \
#      19                               supervision_type = supervision_t)
#      21 aggr_fed(CLIENTS, WEIGHTS_CL, nets, fed_name='global')
#      22 ################### test ##############################
#
# File ~\Desktop\Università\Tesi magistrale\FedMix\helper.py:447, in train_model(trainloader, net_stu, optimizer_stu, device, acc, loss, supervision_type, warmup, CE_LOSS, FedMix_network)
#     445 labeled_iter = iter(trainloader)
#     446 for _ in range(labeled_len):
# --> 447     imgs, masks, y_pl = next(labeled_iter)
#     448     imgs, masks = imgs.to(device), masks.to(device)
#     449     optimizer_stu.zero_grad()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py:1345, in _MultiProcessingDataLoaderIter._next_data(self)
#    1343 else:
#    1344     del self._task_info[idx]
# -> 1345     return self._process_data(data)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py:1371, in _MultiProcessingDataLoaderIter._process_data(self, data)
#    1369 self._try_put_index()
#    1370 if isinstance(data, ExceptionWrapper):
# -> 1371     data.reraise()
#    1372 return data
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_utils.py:694, in ExceptionWrapper.reraise(self)
#     690 except TypeError:
#     691     # If the exception takes multiple arguments, don't try to
#     692     # instantiate since we don't know how to
#     693     raise RuntimeError(msg) from None
# --> 694 raise exception
#
# RuntimeError: Caught RuntimeError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "C:\Users\utente\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\_utils\worker.py", line 308, in _worker_loop
#     data = fetcher.fetch(index)
#   File "C:\Users\utente\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\_utils\fetch.py", line 51, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "C:\Users\utente\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\_utils\fetch.py", line 51, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "C:\Users\utente\Desktop\Università\Tesi magistrale\FedMix\helper.py", line 165, in __getitem__
#     w_min, w_max, h_min, h_max = torch.min(w)-margin[0], \
# RuntimeError: min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.

# %%
IMAGE_SIZE[0]
# Out:
# 256

# %%
from PIL import Image

# Verifica delle dimensioni delle immagini
for img_path in x_train + x_test:
    img = Image.open(img_path)
    width, height = img.size
    if width != IMAGE_SIZE[0] or height != IMAGE_SIZE[1]:
        print("Immagine con dimensioni non valide:", img_path)

# Verifica delle dimensioni delle etichette
for label_path in y_train + y_test:
    label = Image.open(label_path)
    width, height = label.size
    if width != IMAGE_SIZE[0] or height != IMAGE_SIZE[1]:
        print("Etichetta con dimensioni non valide:", label_path)
# Out:
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_001.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_002.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_003.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_004.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_005.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_006.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_007.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_008.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_009.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_010.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_011.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_012.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_013.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_014.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_015.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_016.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_017.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_018.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_019.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_020.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_021.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_022.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_023.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_024.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_025.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_026.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_027.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_031.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_032.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_033.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_034.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_036.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_038.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_039.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_040.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_041.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_042.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_043.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_044.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_047.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_048.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_049.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_050.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_051.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_052.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_053.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_054.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_055.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_057.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_058.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_059.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_060.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_061.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_062.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_063.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_064.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_065.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_066.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_067.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_068.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_069.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_071.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_072.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_073.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_074.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_075.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_076.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_077.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_078.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_079.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_080.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_082.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_083.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_084.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_085.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_086.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_087.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_088.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_089.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_091.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_092.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_093.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_095.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_096.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_097.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_098.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_099.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_100.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_102.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_103.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_104.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_105.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_106.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_107.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_108.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_109.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_110.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_111.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_112.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_113.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_114.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_115.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_116.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_117.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_118.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_119.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_121.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_122.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_123.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_124.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_125.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_126.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_127.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_128.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_129.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_130.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_131.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_132.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_134.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_135.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_136.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_137.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_138.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_139.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_140.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_141.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_142.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_143.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_144.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_145.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_146.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_147.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_148.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_149.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_151.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_152.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_153.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_154.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_157.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_158.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_159.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns_160.png
# Immagine con dimensioni non valide: C:/Users/utente/Desktop/Università/Tesi magistrale/FedMix/data/imagesTrGray\bns